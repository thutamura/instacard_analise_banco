# %%
#bibliotecas
from os import sep
from pydoc import describe
import pandas as pd
import numpy as np # linear algebra
#biblioteca para correlação
import seaborn as sn
# Analise de dados - aisles
#importacao
caminho_aisles =  'C:/ArthurTamura/Novo_Arthur/Tera Dados/Projetos/insta/instacart/aisles/aisles.csv'
dataset_aisles  = pd.read_csv (caminho_aisles,sep = ',', index_col=0 )

# %%
#analise da estrutura
dataset_aisles .info()
dataset_aisles .head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 134 entries, 1 to 134
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   aisle   134 non-null    object
# dtypes: object(1)
# memory usage: 2.1+ KB
#                                aisle
# aisle_id
# 1              prepared soups salads
# 2                  specialty cheeses
# 3                energy granola bars
# 4                      instant foods
# 5         marinades meat preparation

# %%
# Analise de dados - departments
#importacao
caminho_departments =  'C:/ArthurTamura/Novo_Arthur/Tera Dados/Projetos/insta/instacart/departments/departments.csv'
dataset_departments = pd.read_csv (caminho_departments,sep = ',', index_col=0 )

# %%
#analise da estrutura
dataset_departments.info()
dataset_departments.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21 entries, 1 to 21
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   department  21 non-null     object
# dtypes: object(1)
# memory usage: 336.0+ bytes
#               department
# department_id
# 1                 frozen
# 2                  other
# 3                 bakery
# 4                produce
# 5                alcohol

# %%
# Analise de dados - products
#importacao
caminho_products =  'C:/ArthurTamura/Novo_Arthur/Tera Dados/Projetos/insta/instacart/products/products.csv'
dataset_products = pd.read_csv (caminho_products,sep = ',', index_col=0 )

# %%
#analise da estrutura
dataset_products.info()
dataset_products.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49688 entries, 1 to 49688
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_name   49688 non-null  object
#  1   aisle_id       49688 non-null  int64
#  2   department_id  49688 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 1.5+ MB
#                                                  product_name  aisle_id  \
# product_id
# 1                                  Chocolate Sandwich Cookies        61
# 2                                            All-Seasons Salt       104
# 3                        Robust Golden Unsweetened Oolong Tea        94
# 4           Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 5                                   Green Chile Anytime Sauce         5
#
#             department_id
# product_id
# 1                      19
# 2                      13
# 3                       7
# ...

# %%
# Analise de dados - order_products__prior
#importacao
caminho_order_products__prior =  'C:/ArthurTamura/Novo_Arthur/Tera Dados/Projetos/insta/instacart/order_products__prior/order_products__prior.csv'
dataset_order_products__prior = pd.read_csv (caminho_order_products__prior,sep = ',', index_col=0 )

# %%
#analise da estrutura
dataset_order_products__prior.info()
dataset_order_products__prior.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32434489 entries, 2 to 3421083
# Data columns (total 3 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   product_id         int64
#  1   add_to_cart_order  int64
#  2   reordered          int64
# dtypes: int64(3)
# memory usage: 989.8 MB
#           product_id  add_to_cart_order  reordered
# order_id
# 2              33120                  1          1
# 2              28985                  2          1
# 2               9327                  3          0
# 2              45918                  4          1
# 2              30035                  5          0

# %%
# Analise de dados - order
#importacao
caminho_orders =  'C:/ArthurTamura/Novo_Arthur/Tera Dados/Projetos/insta/instacart/orders/orders.csv'
dataset_orders = pd.read_csv (caminho_orders,sep = ',', index_col=0 )

# %%
#analise da estrutura
dataset_orders.info()
dataset_orders.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3421083 entries, 2539329 to 272231
# Data columns (total 6 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   user_id                 int64
#  1   eval_set                object
#  2   order_number            int64
#  3   order_dow               int64
#  4   order_hour_of_day       int64
#  5   days_since_prior_order  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 182.7+ MB
#           user_id eval_set  order_number  order_dow  order_hour_of_day  \
# order_id
# 2539329         1    prior             1          2                  8
# 2398795         1    prior             2          3                  7
# 473747          1    prior             3          3                 12
# 2254736         1    prior             4          4                  7
# 431534          1    prior             5          4                 15
#
#           days_since_prior_order
# order_id
# ...

# %%
# análise de correlação
# ρ = 0,9 a 1 (positivo ou negativo): correlação muito forte;
# ρ = 0,7 a 09 (positivo ou negativo): correlação forte;
# ρ = 0,5 a 0,7 (positivo ou negativo): correlação moderada;
# ρ = 0,3 a 0,5 (positivo ou negativo): correlação fraca;
# ρ = 0 a 0,3 (positivo ou negativo): não possui correlação.
correlation_Orders = dataset_orders.corr()

# %%
# plot da matriz de correlação
plot = sn.heatmap(correlation_Orders, annot = True, fmt=".1f", linewidths=.6)
plot
# Out:
# <AxesSubplot:>

# %%
# Analise de dados - order_products__train
#importacao
caminho_order_products__train =  'C:/ArthurTamura/Novo_Arthur/Tera Dados/Projetos/insta/instacart/order_products__train/order_products__train.csv'
dataset_order_products__train = pd.read_csv (caminho_order_products__train,sep = ',', index_col=0 )

# %%
#analise da estrutura
dataset_order_products__train.info()
dataset_order_products__train.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1384617 entries, 1 to 3421070
# Data columns (total 3 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   product_id         1384617 non-null  int64
#  1   add_to_cart_order  1384617 non-null  int64
#  2   reordered          1384617 non-null  int64
# dtypes: int64(3)
# memory usage: 42.3 MB
#           product_id  add_to_cart_order  reordered
# order_id
# 1              49302                  1          1
# 1              11109                  2          1
# 1              10246                  3          0
# 1              49683                  4          0
# 1              43633                  5          1

# %%
# Analise de dados - sample_submission
#importacao
caminho_sample_submission =  'C:/ArthurTamura/Novo_Arthur/Tera Dados/Projetos/insta/instacart/sample_submission/sample_submission.csv'
dataset_sample_submission = pd.read_csv (caminho_sample_submission,sep = ',', index_col=0 )

# %%
#analise da estrutura
dataset_sample_submission.info()
dataset_sample_submission.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 75000 entries, 17 to 3421054
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   products  75000 non-null  object
# dtypes: object(1)
# memory usage: 1.1+ MB
#              products
# order_id
# 17        39276 29259
# 34        39276 29259
# 137       39276 29259
# 182       39276 29259
# 257       39276 29259

# %%
# We keep only the prior orders
users = dataset_orders[dataset_orders['eval_set'] == 'prior']
users['days_since_prior_order'].dropna()

# We group orders by user_id & calculate the variables based on different user_id
users = users.groupby('user_id').agg(
    
 user_orders= ('order_number' , max),
 user_period=('days_since_prior_order', sum),
 user_mean_days_since_prior = ('days_since_prior_order','mean')
    
)
users.head()
# Out:
#          user_orders  user_period  user_mean_days_since_prior
# user_id
# 1                 10        176.0                   19.555556
# 2                 14        198.0                   15.230769
# 3                 12        133.0                   12.090909
# 4                  5         55.0                   13.750000
# 5                  4         40.0                   13.333333

# %%
# We create a new table "orders_products" which contains the tables "orders" and "order_products_prior"
orders_products =pd.merge(dataset_orders , dataset_order_products__prior, on='order_id', how='inner')

# Getting the number of products in each basket(order)
groupedorders_products = orders_products.groupby(['order_id']).agg(
    basket_size = ('product_id', 'count')
).reset_index()
orders_products = orders_products.merge(groupedorders_products, on='order_id', how='left')
orders_products.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2539329        1    prior             1          2                  8
# 2   2539329        1    prior             1          2                  8
# 3   2539329        1    prior             1          2                  8
# 4   2539329        1    prior             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#    basket_size
# 0            5
# 1            5
# 2            5
# 3            5
# 4            5

# %%
correlation_Ordersproducts = orders_products.corr()
# plot da matriz de correlação
plot = sn.heatmap(correlation_Ordersproducts, annot = True, fmt=".1f", linewidths=.6)
plot
# Out:
# <AxesSubplot:>

# %%
orders_products['p_reordered']= orders_products['reordered']==1
orders_products['non_first_order']= orders_products['order_number']>1

us=orders_products

# We group orders_products by user_id & calculate the variables based on different user_id
us=orders_products.groupby('user_id').agg(
    
     user_total_products =('user_id','count') ,
     p_reordered =('p_reordered', sum) ,
     non_first_order =('non_first_order', sum),
     user_distinct_products=('product_id','nunique')

).reset_index()
#    us['user_reorder_ratio'] = sum(reordered == 1) / sum(order_number > 1)
us['user_reorder_ratio']=us['p_reordered']/us['non_first_order']

del us["p_reordered"],us["non_first_order"]
del orders_products['p_reordered' ],orders_products['non_first_order']

us.head(20)
# Out:
#     user_id  user_total_products  user_distinct_products  user_reorder_ratio
# 0         1                   59                      18            0.759259
# 1         2                  195                     102            0.510989
# 2         3                   88                      33            0.705128
# 3         4                   18                      17            0.071429
# 4         5                   37                      23            0.538462
# 5         6                   14                      12            0.200000
# 6         7                  206                      68            0.711340
# 7         8                   49                      36            0.464286
# 8         9                   76                      58            0.391304
# 9        10                  143                      94            0.355072
# 10       11                   94                      61            0.407407
# ...

# %% [markdown]
# Em seguida, combinamos as tabelas users e us usando a função inner_join() e calculamos a variável final:
#
# user_average_basket: número médio de itens da cesta por pedido por usuário

# %%
users =pd.merge(users,us ,on='user_id',  how='inner')

# We calculate the user_average_basket variable
users['user_average_basket'] = users['user_total_products'] / users['user_orders']
users.head()
# Out:
#    user_id  user_orders  user_period  user_mean_days_since_prior  \
# 0        1           10        176.0                   19.555556
# 1        2           14        198.0                   15.230769
# 2        3           12        133.0                   12.090909
# 3        4            5         55.0                   13.750000
# 4        5            4         40.0                   13.333333
#
#    user_total_products  user_distinct_products  user_reorder_ratio  \
# 0                   59                      18            0.759259
# 1                  195                     102            0.510989
# 2                   88                      33            0.705128
# 3                   18                      17            0.071429
# 4                   37                      23            0.538462
#
#    user_average_basket
# 0             5.900000
# 1            13.928571
# 2             7.333333
# 3             3.600000
# 4             9.250000

# %% [markdown]
# #correlation_users = users.corr()
# # plot da matriz de correlação
# #plot = sn.heatmap(correlation_users, annot = True, fmt=".1f", linewidths=.6)
# #plot

# %% [markdown]
# Agora identificamos o pedido futuro por usuário e os adicionamos na tabela de usuários. Os pedidos futuros são indicados como treinar e testar na variável eval_set. Como resultado, saberemos qual é o order_id do pedido futuro por usuário, se esse pedido pertence ao conjunto de trem ou teste e o tempo em dias desde o último pedido.

# %%
# we exclude prior orders and thus we keep only train and test orders
us = dataset_orders[dataset_orders['eval_set'] != 'prior']
us['time_since_last_order'] = us['days_since_prior_order']
us['future_order_dow'] = us['order_dow']
us['future_order_hour_of_day'] = us['order_hour_of_day']

us = us[['user_id','order_number','eval_set','time_since_last_order', 'future_order_dow', 'future_order_hour_of_day']]

# We combine users and us tables and store the results into the users table
users_features = pd.merge(users , us, on='user_id', how='inner') 

# We delete the us table
del us, users

users_features.head()
# Out:
# C:\Users\thuta\AppData\Local\Temp\ipykernel_12104\1189165849.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   us['time_since_last_order'] = us['days_since_prior_order']
# C:\Users\thuta\AppData\Local\Temp\ipykernel_12104\1189165849.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   us['future_order_dow'] = us['order_dow']
# C:\Users\thuta\AppData\Local\Temp\ipykernel_12104\1189165849.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# Número total de pedidos por produto
# Posição média no carrinho para o produto

# %%
# Helper functions to be able to correclty calculate the avergae of hours
# The problem is that if we deal with hours and average them normally, the average of 1:00 and 23:00 will be 12 not 0:00
import datetime
import math

def datetime_to_radians(x):
    # radians are calculated using a 24-hour circle, not 12-hour, starting at north and moving clockwise
    seconds_from_midnight = 3600 * x
    radians = float(seconds_from_midnight) / float(12 * 60 * 60) * 2.0 * math.pi
    return radians

def average_angle(angles):
    # angles measured in radians
    x_sum = np.sum(np.sin(angles))
    y_sum = np.sum(np.cos(angles))
    x_mean = x_sum / float(len(angles))
    y_mean = y_sum / float(len(angles))
    return np.arctan2(x_mean, y_mean)

def radians_to_time_of_day(x):
    # radians are measured clockwise from north and represent time in a 24-hour circle
    seconds_from_midnight = int(float(x) / (2.0 * math.pi) * 12.0 * 60.0 * 60.0)
    hour = seconds_from_midnight // 3600 % 24
    minute = (seconds_from_midnight % 3600) // 60
    second = seconds_from_midnight % 60
    return datetime.time(hour, minute, second)
    
def average_times_of_day(x):
    # input datetime.datetime array and output datetime.time value
    angles = [datetime_to_radians(y) for y in x]
    avg_angle = average_angle(angles)
    return radians_to_time_of_day(avg_angle)

def day_to_radians(day):
    radians = float(day) / float(7) * 2.0 * math.pi
    return radians
def radians_to_days(x):
    day = int(float(x) / (2.0 * math.pi) * 7) % 7
    return day
def average_days(x):
    angles = [day_to_radians(y) for y in x]
    avg_angle = average_angle(angles)
    return radians_to_days(avg_angle)

# %%
prod_features = orders_products.groupby(['product_id']).agg(
    prod_freq = ('order_id', 'count'),
    prod_avg_position = ('add_to_cart_order', 'mean'),
    prod_avg_hour = ('order_hour_of_day', average_times_of_day),
    prod_avg_dow = ('order_dow', average_days)
).reset_index()

prod_features.head(20)
# Out:
#     product_id  prod_freq  prod_avg_position prod_avg_hour  prod_avg_dow
# 0            1       1852           5.801836      23:36:11             2
# 1            2         90           9.888889      00:43:10             0
# 2            3        277           6.415162      22:00:19             0
# 3            4        329           9.507599      01:29:15             0
# 4            5         15           6.466667      23:06:53             0
# 5            6          8          14.125000      01:08:12             0
# 6            7         30           7.966667      02:13:16             6
# 7            8        165           8.418182      00:21:10             0
# 8            9        156           7.608974      23:45:04             0
# 9           10       2572           8.816874      23:18:05             0
# 10          11        104           8.471154      00:31:26             1
# 11          12        246           8.349593      20:09:12             6
# ...

# %% [markdown]
# Probabilidade de um produto ser reordenado após o primeiro pedido
# Em média, quantas vezes um produto foi comprado pelos usuários que o compraram pelo menos uma vez

# %%
non_first_order = orders_products['order_number'] != 1

groupedorders_products = orders_products[non_first_order].groupby(['product_id']).agg(
    prod_reorder_ratio = ('reordered', 'mean')
).reset_index()

prod_features = prod_features.merge(groupedorders_products, on='product_id', how='left')

# Group by users who have bought it more than once
# get the count of orders each user bought having the product. 
groupedorders_products = orders_products[non_first_order].groupby(['product_id', 'user_id']).agg(
    user_prod_freq = ('order_id', 'count')
).reset_index()

# get the avg # of orders the user will buy having that product after buying it for the first time
groupedorders_products = groupedorders_products.groupby(['product_id']).agg(
    user_prod_avg_freq = ('user_prod_freq', 'mean')
).reset_index()

prod_features = prod_features.merge(groupedorders_products, on='product_id', how='left')
del groupedorders_products, non_first_order

prod_features.head()
# Out:
#    product_id  prod_freq  prod_avg_position prod_avg_hour  prod_avg_dow  \
# 0           1       1852           5.801836      23:36:11             2
# 1           2         90           9.888889      00:43:10             0
# 2           3        277           6.415162      22:00:19             0
# 3           4        329           9.507599      01:29:15             0
# 4           5         15           6.466667      23:06:53             0
#
#    prod_reorder_ratio  user_prod_avg_freq
# 0            0.647662            2.641566
# 1            0.137931            1.160000
# 2            0.780769            3.714286
# 3            0.506897            1.746988
# 4            0.642857            2.333333

# %% [markdown]
# Agora criamos preditores que indicam como um usuário se comporta em relação a um produto específico. Armazenamos esses preditores na tabela de dados, que também é a tabela final que criamos. Para isso, usamos as tabelas prd e users.
# Começamos calculando quatro novas variáveis:
# up_orders: o total de vezes que um usuário pediu um produto
#
# up_first_order: Qual foi a primeira vez que um usuário comprou um produto
#
# up_last_order: Qual foi a última vez que um usuário comprou um produto
#
# up_average_cart_position: a posição média no carrinho de um usuário de um produto

# %%
# We create the data table starting from the orders_products table 
data = orders_products

data = data.groupby(['user_id','product_id']).agg(

 up_orders= ('product_id', 'count'),
 up_first_order=('order_number', min),
 up_last_order = ('order_number',max),
 up_average_cart_position = ('add_to_cart_order','mean')
 ,up_avg_hour = ('order_hour_of_day', average_times_of_day),
 up_avg_dow = ('order_dow', average_days)
).reset_index()
 
del orders_products
data.head(20)
# Out:
#     user_id  product_id  up_orders  up_first_order  up_last_order  \
# 0         1         196         10               1             10
# 1         1       10258          9               2             10
# 2         1       10326          1               5              5
# 3         1       12427         10               1             10
# 4         1       13032          3               2             10
# 5         1       13176          2               2              5
# 6         1       14084          1               1              1
# 7         1       17122          1               5              5
# 8         1       25133          8               3             10
# 9         1       26088          2               1              2
# 10        1       26405          2               1              4
# 11        1       30450          1               3              3
# 12        1       35951          1              10             10
# ...

# %% [markdown]
# Em seguida, compilamos a tabela de dados com as tabelas prd e users e calculamos as três variáveis finais.
#
# up_order_rate: Porcentagem de pedidos do usuário que incluem um produto específico
#
# up_orders_since_last_order: número de pedidos desde o último pedido do usuário de um produto
#
# up_order_rate_since_first_order: porcentagem de pedidos desde o primeiro pedido de um produto em que um usuário comprou este produto

# %%
# up_order_rate = up_orders / user_total_products
data = data.merge(users_features[['user_id','user_orders']], on='user_id' , how='left')
data['up_order_rate'] = data['up_orders']/data['user_orders']

# up_orders_since_last_order = user_last_order - user_last_ordered_that_product
data['up_orders_since_last_order'] = data['user_orders'] - data['up_last_order']

# From the moment the user know about the product, how frequent he then bought it in his next orders?
# up_order_rate_since_first_order = up_orders / (user_orders - up_first_order + 1)
# The + 1 is added since order_numbering starts from 1 not 0
data['up_order_rate_since_first_order'] = data['up_orders']/(data['user_orders'] - data['up_first_order'] + 1)
del data['user_orders']

data.head(100)
# Out:
#     user_id  product_id  up_orders  up_first_order  up_last_order  \
# 0         1         196         10               1             10
# 1         1       10258          9               2             10
# 2         1       10326          1               5              5
# 3         1       12427         10               1             10
# 4         1       13032          3               2             10
# ..      ...         ...        ...             ...            ...
# 95        2       38656          1               5              5
# 96        2       39877          1              13             13
# 97        2       39928          1              14             14
# 98        2       40198          2               7              8
# 99        2       40571          1               6              6
#
#     up_average_cart_position up_avg_hour  up_avg_dow  up_order_rate  \
# 0                   1.400000    19:00:00           2       1.000000
# ...

# %%
# Mesclando recursos de usuário e produto com o dataframe de recursos finais
data = data.merge(users_features, on='user_id', how='left').merge(prod_features, on='product_id', how='left')
del users_features, prod_features

order_products_future = dataset_order_products__train.merge(orders, on='order_id', how='left')
order_products_future = order_products_future[['user_id', 'product_id', 'reordered']]
data = data.merge(order_products_future, on=['user_id', 'product_id'], how='left')

# Defina 0 como Produto que não existe no pedido futuro para que o modelo possa predizê-los como Não no pedido futuro.
data['reordenado'].fillna(0, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Input In [48], in <cell line: 2>()
#       1 # Mesclando recursos de usuário e produto com o dataframe de recursos finais
# ----> 2 data = data.merge(users_features, on='user_id', how='left').merge(prod_features, on='product_id', how='left')
#       3 del users_features, prod_features
#       5 order_products_future = dataset_order_products__train.merge(orders, on='order_id', how='left')
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:9345, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9326 @Substitution("")
#    9327 @Appender(_merge_doc, indents=2)
#    9328 def merge(
#    (...)
#    9341     validate: str | None = None,
#    9342 ) -> DataFrame:
#    9343     from pandas.core.reshape.merge import merge
# ...

# %% [markdown]
# Preditores dependentes do tempo
#
# Dependente do usuário
#
# Na hora média em que o usuário compra este produto em - A hora do pedido futuro.
# Em média em qual dia da semana o usuário compra este produto - O dia da semana do pedido futuro.
#
# Dependente do produto
# Na hora média em que o produto é mais comprado - A hora do pedido futuro.
# Em média em qual dia da semana o produto é mais comprado - Dia da semana do pedido futuro
#
# Frequência de compra deste produto na hora do dia do pedido do futuro. [Ainda não implementado]
# Frequência de compra deste produto no dia da semana do pedido futuro. [Ainda não implementado]
